# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
gender = ['Male', 'Female']
count = [55, 45]

# Create bar chart
plt.bar(gender, count)

# Labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender in Population')

# Show graph
plt.show()
